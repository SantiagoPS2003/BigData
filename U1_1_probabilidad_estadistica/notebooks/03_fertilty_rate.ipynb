# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# import requests

# Fetch the data.
df = pd.read_csv("https://ourworldindata.org/grapher/children-born-per-woman.csv?v=1&csvType=full&useColumnShortNames=true", storage_options = {'User-Agent': 'Our World In Data data fetch/1.0'})

# Fetch the metadata
# metadata = requests.get("https://ourworldindata.org/grapher/children-born-per-woman.metadata.json?v=1&csvType=full&useColumnShortNames=true").json()

# %%
df.shape
# Out:
# (19402, 4)

# %%
japon = df[df["entity"] == "Japan"]
mexico = df[df["entity"] == "Mexico"]

# %%
japon.head(3)
# Out:
#      entity code  year  fertility_rate_hist
# 8384  Japan  JPN  1947                4.614
# 8385  Japan  JPN  1948                4.463
# 8386  Japan  JPN  1949                4.373

# %%
mexico.head(3)
# Out:
#        entity code  year  fertility_rate_hist
# 11125  Mexico  MEX  1950                6.709
# 11126  Mexico  MEX  1951                6.727
# 11127  Mexico  MEX  1952                6.731

# %%
anios_mexico = mexico["year"].to_numpy()
tasa_mexico = mexico ["fertility_rate_hist"].to_numpy()

anios_japon = japon["year"].to_numpy()
tasa_japon = japon ["fertility_rate_hist"].to_numpy()

# %%
type(anios_mexico)
# Out:
# numpy.ndarray

# %%
type(anios_japon)
# Out:
# numpy.ndarray

# %%
promedio_mexico = np.mean(tasa_mexico)
maximo_mexico = np.max(tasa_mexico)

minimo_mexico = np.min(tasa_mexico)
desviacion_mexico = np.std(tasa_mexico)

# %%
promedio_japon = np.mean(tasa_japon)
max_japon = np.max(tasa_japon)
min_japon = np.min(tasa_japon)
std_japon = np.std(tasa_japon)

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    anios_mexico,
    tasa_mexico,
    label="Mexico"
)

plt.title("Evolucion de la tasa de natalidad de Mexico")
plt.xlabel("Anio")
plt.ylabel("Nacimientos por acada 1,000 habitantes")
plt.grid(True)
plt.legend()

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    anios_japon,
    tasa_japon,
    label="Japon"
)

plt.title("Evolucion de la tasa de natalidad de Japon")
plt.xlabel("Anio")
plt.ylabel("Nacimientos por cada 1,000 habitantes")
plt.grid(True)
plt.legend()

# %%
plt.figure(figsize=(10, 5))

plt.plot(
    anios_mexico,
    tasa_mexico,
    label="Mexico"
)

plt.plot(
    anios_japon,
    tasa_japon,
    label="Japon"
)

plt.title("Comparacion de la tasa de natalidad ")
plt.xlabel("Anio")
plt.ylabel("Nacimientos por cada 1,000 habitantes")
plt.grid(True)
plt.legend()

# %%
mascara_coincidencia_anios = anios_japon >= anios_mexico.min()
mascara_coincidencia_anios
# Out:
# array([False, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
anios_japon = anios_japon[mascara_coincidencia_anios]

# %%
anios_japon.shape
anios_japon
# Out:
# array([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#        1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])

# %%
tasa_japon = tasa_japon[mascara_coincidencia_anios]

# %%
tasa_japon.shape
# Out:
# (74,)

# %%
diferencia_mc_jp = tasa_mexico - tasa_japon

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    anios_japon,
    tasa_japon,
    label="Japon"
)
plt.plot(
    anios_mexico,
    tasa_mexico,
    label="Mexico"
)
plt.plot(
    anios_mexico,
    diferencia_mc_jp,
    label="Diferencia"
)

plt.title("Comparacion de la tasa de natalidad")
plt.xlabel("Anio")
plt.ylabel("Nacimientos por cada 1,000 habitantes")
plt.grid(True)
plt.legend()

# %%
brazil = df[df["entity"] == "Brazil"]
anios_brazil = brazil["year"].to_numpy()
tasa_brazil = brazil ["fertility_rate_hist"].to_numpy()

# %%
mascara_coincidencia_anios_bz = anios_brazil >= anios_mexico.min()
mascara_coincidencia_anios_bz
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
diferencia_mc_bz = tasa_mexico - tasa_brazil

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    anios_brazil,
    tasa_brazil,
    label="Brazil"
)
plt.plot(
    anios_mexico,
    tasa_mexico,
    label="Mexico"
)
plt.plot(
    anios_mexico,
    diferencia_mc_bz,
    label="Diferencia"
)

plt.title("Comparacion de la tasa de natalidad")
plt.xlabel("Anio")
plt.ylabel("Nacimientos por cada 1,000 habitantes")
plt.grid(True)
plt.legend()

# %%
#
anios_comunes = np.intersect1d(
    anios_mexico,
    anios_japon
)
anios_comunes
# Out:
# array([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#        1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])

# %%
comparacion_mexico_japon = pd.merge(
    mexico[["year","fertility_rate_hist"]],
    japon[["year","fertility_rate_hist"]],
    on="year",
    suffixes=("_mexico","_japon")
)
comparacion_mexico_japon
# Out:
#     year  fertility_rate_hist_mexico  fertility_rate_hist_japon
# 0   1950                       6.709                      3.615
# 1   1951                       6.727                      3.225
# 2   1952                       6.731                      2.947
# 3   1953                       6.734                      2.673
# 4   1954                       6.745                      2.468
# ..   ...                         ...                        ...
# 69  2019                       2.020                      1.323
# 70  2020                       1.990                      1.304
# 71  2021                       1.970                      1.275
# 72  2022                       1.940                      1.256
# 73  2023                       1.910                      1.208
#
# [74 rows x 3 columns]

# %%
mexico_anios_comun = mexico[mexico["year"].isin(anios_comunes)]
japon_anios_comun = japon[japon["year"].isin(anios_comunes)]

# %%
mexico_tasa_comun = mexico_anios_comun["fertility_rate_hist"].isin(anios_comunes)
japon_tasa_comun = japon_anios_comun["fertility_rate_hist"].isin(anios_comunes)

# %%
anios_japon = np.delete(anios_comunes, [23,25,30,42,48])

# %%
mex_anios_comunes = mexico_anios_comun["year"].to_numpy()
jpn_anios_comunes = japon_anios_comun["year"].to_numpy()

mex_tasa_comunes = mexico_anios_comun["fertility_rate_hist"].to_numpy()
jpn_tasa_comunes = japon_anios_comun["fertility_rate_hist"].to_numpy()
